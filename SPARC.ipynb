# %%
# !git clone https://github.com/nishchaypagarani/SPARC.git
# %cd SPARC
# Out:
# Cloning into 'SPARC'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 50 (delta 15), reused 10 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (50/50), 1.84 MiB | 3.25 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# /home/7h/projects/589/589Project/SPARC

# %%
# !pip install scipy scikit-learn
# Out:
# ...
#   Using cached numpy-2.3.5-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 1.7 MB/s eta 0:00:0000:0100:01
# Using cached numpy-2.3.5-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 3.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [scikit-learn] [scikit-learn]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install gdown
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [gdown]m10/12 [beautifulsoup4]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import gdown
# !gdown 1KJ0Mi1jPRUQZ5Ps52XUfoY0rAF3DU26T
# !gdown 1VcprMvq6SB82ObSS20ZLvwbDg3DKbavC
# !gdown 1aFpeeD7xguudSe_xhcJ3zoOUCw5DCUsg
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1KJ0Mi1jPRUQZ5Ps52XUfoY0rAF3DU26T
# From (redirected): https://drive.google.com/uc?id=1KJ0Mi1jPRUQZ5Ps52XUfoY0rAF3DU26T&confirm=t&uuid=ba75753b-c2de-486f-a960-431a9f0d1bc4
# To: /home/7h/projects/589/589Project/SPARC/SPARCData-20251212T212934Z-3-001.zip
# 100%|███████████████████████████████████████| 1.21G/1.21G [00:11<00:00, 106MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1VcprMvq6SB82ObSS20ZLvwbDg3DKbavC
# From (redirected): https://drive.google.com/uc?id=1VcprMvq6SB82ObSS20ZLvwbDg3DKbavC&confirm=t&uuid=c25f8a5c-09c5-41ff-aa50-ebdaca231062
# To: /home/7h/projects/589/589Project/SPARC/SPARCData-20251212T212934Z-3-002.zip
# 100%|███████████████████████████████████████| 1.33G/1.33G [00:12<00:00, 106MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1aFpeeD7xguudSe_xhcJ3zoOUCw5DCUsg
# ...

# %%
# !unzip SPARCData-20251212T212934Z-3-001.zip
# !unzip SPARCData-20251212T212934Z-3-002.zip
# !unzip SPARCData-20251212T212934Z-3-003.zip
# Out:
# Archive:  SPARCData-20251212T212934Z-3-001.zip
#   inflating: SPARCData/VOC2007_test_baseline_zsclip_cossims_RN50x64_ensemble_80.pkl
#   inflating: SPARCData/VOC2007_test_simple_single_and_compound_cossims_RN50x16.pkl
#   inflating: SPARCData/VOC2007_test_baseline_zsclip_cossims_RN101_ensemble_80.pkl
#   inflating: SPARCData/VOC2007_test_baseline_zsclip_cossims_RN50x4_ensemble_80.pkl
#   inflating: SPARCData/VOC2007_test_baseline_zsclip_cossims_ViT-B32_ensemble_80.pkl
#   inflating: SPARCData/VOC2007_test_baseline_zsclip_cossims_RN50_ensemble_80.pkl
#   inflating: SPARCData/VOC2007_test_simple_single_and_compound_cossims_RN50x4.pkl
#   inflating: SPARCData/VOC2007_test_simple_single_and_compound_cossims_ViT-L14336px.pkl
#   inflating: SPARCData/VOC2007_test_baseline_zsclip_cossims_ViT-B16_ensemble_80.pkl
#   inflating: SPARCData/VOC2007_test_baseline_zsclip_cossims_ViT-L14_ensemble_80.pkl
#   inflating: SPARCData/VOC2007_test_simple_single_and_compound_cossims_RN101.pkl
# ...

# %%
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=COCO2014 --model_type=ViT-B16 --output_prefix=ViT-L14-COCO
# Out:
# load data...
# 100%|███████████████████████████████████████| 768/768 [00:00<00:00, 9888.25it/s]
# Low number of compound prompts for class "airplane": "Airplane and Truck", "Airplane and Person", "Airplane and Car"
# Low number of compound prompts for class "bear": "Bear and Person"
# Low number of compound prompts for class "elephant": "Bench and Elephant", "Elephant and Person", "Car and Elephant"
# Low number of compound prompts for class "giraffe": "Bird and Giraffe", "Giraffe and Zebra", "Giraffe and Person"
# Low number of compound prompts for class "skis": "Person and Skis", "Skis and Snowboard", "Backpack and Skis"
# Low number of compound prompts for class "snowboard": "Person and Snowboard", "Skis and Snowboard", "Backpack and Snowboard"
# Low number of compound prompts for class "zebra": "Bird and Zebra", "Person and Zebra", "Giraffe and Zebra"
# uncalibrated_APs...
# normalize...
# rank and fuse...
# ...

# %%
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=COCO2014 --model_type=ViT-L14336px --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=COCO2014 --model_type=ViT-L14 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=COCO2014 --model_type=ViT-B16 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=COCO2014 --model_type=ViT-B32 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=COCO2014 --model_type=RN50x64 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=COCO2014 --model_type=RN50x16 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=COCO2014 --model_type=RN50x4 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=COCO2014 --model_type=RN101 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=COCO2014 --model_type=RN50 --output_prefix=ViT-L14-COCO
# Out:
# load data...
# 100%|███████████████████████████████████████| 768/768 [00:00<00:00, 9863.84it/s]
# Low number of compound prompts for class "airplane": "Airplane and Truck", "Airplane and Person", "Airplane and Car"
# Low number of compound prompts for class "bear": "Bear and Person"
# Low number of compound prompts for class "elephant": "Bench and Elephant", "Elephant and Person", "Car and Elephant"
# Low number of compound prompts for class "giraffe": "Bird and Giraffe", "Giraffe and Zebra", "Giraffe and Person"
# Low number of compound prompts for class "skis": "Person and Skis", "Skis and Snowboard", "Backpack and Skis"
# Low number of compound prompts for class "snowboard": "Person and Snowboard", "Skis and Snowboard", "Backpack and Snowboard"
# Low number of compound prompts for class "zebra": "Bird and Zebra", "Person and Zebra", "Giraffe and Zebra"
# uncalibrated_APs...
# normalize...
# rank and fuse...
# ...

# %%
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=VOC2007 --model_type=ViT-L14336px --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=VOC2007 --model_type=ViT-L14 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=VOC2007 --model_type=ViT-B16 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=VOC2007 --model_type=ViT-B32 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=VOC2007 --model_type=RN50x64 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=VOC2007 --model_type=RN50x16 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=VOC2007 --model_type=RN50x4 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=VOC2007 --model_type=RN101 --output_prefix=ViT-L14-COCO
# Out:
# load data...
# 100%|████████████████████████████████████████| 82/82 [00:00<00:00, 34420.83it/s]
# Low number of compound prompts for class "aeroplane": "aeroplane and person", "An aeroplane flies overhead while a person watches from below."
# Low number of compound prompts for class "cow": "cow and person", "cow, person, and horse", "A cow grazes in the field while a farmer stands nearby."
# Low number of compound prompts for class "sheep": "Sheep graze peacefully in the meadow."
# Low number of compound prompts for class "train": "A train rushes past the countryside."
# uncalibrated_APs...
# normalize...
# rank and fuse...
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 115.59it/s]
# APs...
# 100%|█████████████████████████████████████████| 20/20 [00:00<00:00, 2237.44it/s]
# saving results...
# CLIP (baseline): mAP=81.329305
# Normalize only: mAP=87.345016
# SPARC: mAP=88.867886
# load data...
# ...

# %%
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=NUSWIDE --model_type=ViT-L14336px --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=NUSWIDE --model_type=ViT-L14 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=NUSWIDE --model_type=ViT-B16 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=NUSWIDE --model_type=ViT-B32 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=NUSWIDE --model_type=RN50x64 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=NUSWIDE --model_type=RN50x16 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=NUSWIDE --model_type=RN50x4 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=NUSWIDE --model_type=RN101 --output_prefix=ViT-L14-COCO
# !python run_SPARC.py --input_dir="$PWD/SPARCData/" --dataset_name=NUSWIDE --model_type=RN50 --output_prefix=ViT-L14-COCO
# Out:
# load data...
# 100%|███████████████████████████████████████| 497/497 [00:00<00:00, 9915.05it/s]
# Low number of compound prompts for class "book":
# Low number of compound prompts for class "computer":
# Low number of compound prompts for class "dancing":
# Low number of compound prompts for class "earthquake":
# Low number of compound prompts for class "fire": "sky and fire", "sunset and fire", "water and fire"
# Low number of compound prompts for class "food":
# Low number of compound prompts for class "horses": "animal and horses", "animal, horses, and zebra", "Horses gallop past a zebra in an open field."
# Low number of compound prompts for class "map": "sky and map", "street and map", "A map is displayed on a sign at a busy intersection."
# Low number of compound prompts for class "soccer": "beach and soccer", "sports and soccer", "People play soccer on a sandy beach at sunset."
# ...
